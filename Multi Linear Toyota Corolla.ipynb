# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics.regressionplots import influence_plot
import statsmodels.formula.api as smf
import numpy as np

# %%
data= pd.read_csv('ToyotaCorolla.csv', encoding= 'unicode_escape')

# %%
data.columns
# Out:
# Index(['Id', 'Model', 'Price', 'Age_08_04', 'Mfg_Month', 'Mfg_Year', 'KM',
#        'Fuel_Type', 'HP', 'Met_Color', 'Color', 'Automatic', 'cc', 'Doors',
#        'Cylinders', 'Gears', 'Quarterly_Tax', 'Weight', 'Mfr_Guarantee',
#        'BOVAG_Guarantee', 'Guarantee_Period', 'ABS', 'Airbag_1', 'Airbag_2',
#        'Airco', 'Automatic_airco', 'Boardcomputer', 'CD_Player',
#        'Central_Lock', 'Powered_Windows', 'Power_Steering', 'Radio',
#        'Mistlamps', 'Sport_Model', 'Backseat_Divider', 'Metallic_Rim',
#        'Radio_cassette', 'Tow_Bar'],
#       dtype='object')

# %%
data1=pd.concat([data.Price,data.Age_08_04,data.KM,data.HP,data.cc,data.Doors,data.Gears,data.Quarterly_Tax,data.Weight],axis=1)
data1
# Out:
#       Price  Age_08_04     KM   HP    cc  Doors  Gears  Quarterly_Tax  Weight
# 0     13500         23  46986   90  2000      3      5            210    1165
# 1     13750         23  72937   90  2000      3      5            210    1165
# 2     13950         24  41711   90  2000      3      5            210    1165
# 3     14950         26  48000   90  2000      3      5            210    1165
# 4     13750         30  38500   90  2000      3      5            210    1170
# ...     ...        ...    ...  ...   ...    ...    ...            ...     ...
# 1431   7500         69  20544   86  1300      3      5             69    1025
# 1432  10845         72  19000   86  1300      3      5             69    1015
# 1433   8500         71  17016   86  1300      3      5             69    1015
# 1434   7250         70  16916   86  1300      3      5             69    1015
# 1435   6950         76      1  110  1600      5      5             19    1114
#
# [1436 rows x 9 columns]

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Price          1436 non-null   int64
#  1   Age_08_04      1436 non-null   int64
#  2   KM             1436 non-null   int64
#  3   HP             1436 non-null   int64
#  4   cc             1436 non-null   int64
#  5   Doors          1436 non-null   int64
#  6   Gears          1436 non-null   int64
#  7   Quarterly_Tax  1436 non-null   int64
#  8   Weight         1436 non-null   int64
# dtypes: int64(9)
# memory usage: 101.1 KB

# %%
data1.shape
# Out:
# (1436, 9)

# %%
data1.describe()
# Out:
#               Price    Age_08_04             KM           HP           cc  \
# count   1436.000000  1436.000000    1436.000000  1436.000000   1436.00000
# mean   10730.824513    55.947075   68533.259749   101.502089   1576.85585
# std     3626.964585    18.599988   37506.448872    14.981080    424.38677
# min     4350.000000     1.000000       1.000000    69.000000   1300.00000
# 25%     8450.000000    44.000000   43000.000000    90.000000   1400.00000
# 50%     9900.000000    61.000000   63389.500000   110.000000   1600.00000
# 75%    11950.000000    70.000000   87020.750000   110.000000   1600.00000
# max    32500.000000    80.000000  243000.000000   192.000000  16000.00000
#
#              Doors        Gears  Quarterly_Tax      Weight
# count  1436.000000  1436.000000    1436.000000  1436.00000
# mean      4.033426     5.026462      87.122563  1072.45961
# std       0.952677     0.188510      41.128611    52.64112
# min       2.000000     3.000000      19.000000  1000.00000
# ...

# %%
data2=data1.rename({'Age_08_04':'age','Quarterly_Tax':'QT'},axis=1)
data2
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1436 rows x 9 columns]

# %%
data2[data2.duplicated()]
# Out:
#   File "<ipython-input-19-c25c614739e6>", line 1
#     data2[data2.duplicated()
#                             ^
# SyntaxError: unexpected EOF while parsing

# %%
data3=data2.drop_duplicates()
data3
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1431   7500   69  20544   86  1300      3      5   69    1025
# 1432  10845   72  19000   86  1300      3      5   69    1015
# 1433   8500   71  17016   86  1300      3      5   69    1015
# 1434   7250   70  16916   86  1300      3      5   69    1015
# 1435   6950   76      1  110  1600      5      5   19    1114
#
# [1435 rows x 9 columns]

# %%
data3.corr()
# Out:
#            Price       age        KM        HP        cc     Doors     Gears  \
# Price   1.000000 -0.876273 -0.569420  0.314134  0.124375  0.183604  0.063831
# age    -0.876273  1.000000  0.504575 -0.155293 -0.096549 -0.146929 -0.005629
# KM     -0.569420  0.504575  1.000000 -0.332904  0.103822 -0.035193  0.014890
# HP      0.314134 -0.155293 -0.332904  1.000000  0.035207  0.091803  0.209642
# cc      0.124375 -0.096549  0.103822  0.035207  1.000000  0.079254  0.014732
# Doors   0.183604 -0.146929 -0.035193  0.091803  0.079254  1.000000 -0.160101
# Gears   0.063831 -0.005629  0.014890  0.209642  0.014732 -0.160101  1.000000
# QT      0.211508 -0.193319  0.283312 -0.302287  0.305982  0.107353 -0.005125
# Weight  0.575869 -0.466484 -0.023969  0.087143  0.335077  0.301734  0.021238
#
#               QT    Weight
# Price   0.211508  0.575869
# age    -0.193319 -0.466484
# KM      0.283312 -0.023969
# HP     -0.302287  0.087143
# cc      0.305982  0.335077
# Doors   0.107353  0.301734
# ...

# %%
sns.set_style(style='darkgrid')
sns.pairplot(data3)

# %%
data3.columns

# %%
data3.boxplot(column=['HP'])

# %%
import statsmodels.formula.api as smf 
model = smf.ols('Price~age+KM+HP+cc+Doors+Gears+QT+Weight',data=data3).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.863
# Model:                            OLS   Adj. R-squared:                  0.862
# Method:                 Least Squares   F-statistic:                     1118.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        20:49:45   Log-Likelihood:                -12366.
# No. Observations:                1435   AIC:                         2.475e+04
# Df Residuals:                    1426   BIC:                         2.480e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -5472.5404   1412.169     -3.875      0.000   -8242.692   -2702.389
# ...

# %% [markdown]
# p value for cc and Doors is > 0.05; hence coefficient of this 2 are not significant, so need to check individually

# %%
model2 = smf.ols('Price~cc',data=data3).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                  0.015
# Method:                 Least Squares   F-statistic:                     22.52
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           2.29e-06
# Time:                        20:50:44   Log-Likelihood:                -13779.
# No. Observations:                1435   AIC:                         2.756e+04
# Df Residuals:                    1433   BIC:                         2.757e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   9053.5368    363.894     24.880      0.000    8339.715    9767.359
# ...

# %% [markdown]
# cc has significant pvalue

# %%
model3 = smf.ols('Price~Doors',data=data3).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                  0.033
# Method:                 Least Squares   F-statistic:                     49.99
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           2.40e-12
# Time:                        20:51:18   Log-Likelihood:                -13765.
# No. Observations:                1435   AIC:                         2.753e+04
# Df Residuals:                    1433   BIC:                         2.755e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   7916.1452    407.596     19.422      0.000    7116.596    8715.694
# ...

# %% [markdown]
# Doors has significant p value

# %%
model4 = smf.ols('Price~cc+Doors',data=data3).fit()
model4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.046
# Model:                            OLS   Adj. R-squared:                  0.045
# Method:                 Least Squares   F-statistic:                     34.40
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):           2.55e-15
# Time:                        20:52:02   Log-Likelihood:                -13756.
# No. Observations:                1435   AIC:                         2.752e+04
# Df Residuals:                    1432   BIC:                         2.753e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   6568.3395    513.700     12.786      0.000    5560.655    7576.024
# ...

# %% [markdown]
# Both (CC and Doors) together has significant p value

# %% [markdown]
# Check Collinearity
# Variance Inflation Factor

# %%
data3.columns
# Out:
# Index(['Price', 'age', 'KM', 'HP', 'cc', 'Doors', 'Gears', 'QT', 'Weight'], dtype='object')

# %%
rsq_age=smf.ols('age~KM+HP+cc+Doors+Gears+QT+Weight',data=data3).fit().rsquared
vif_age=1/(1-rsq_age)

rsq_KM=smf.ols('KM~age+HP+cc+Doors+Gears+QT+Weight',data=data3).fit().rsquared
vif_KM=1/(1-rsq_KM)

rsq_HP=smf.ols('HP~age+KM+cc+Doors+Gears+QT+Weight',data=data3).fit().rsquared
vif_HP=1/(1-rsq_HP)

rsq_cc=smf.ols('cc~age+KM+HP+Doors+Gears+QT+Weight',data=data3).fit().rsquared
vif_cc=1/(1-rsq_cc)

rsq_Door=smf.ols('Doors~age+KM+HP+cc+Gears+QT+Weight',data=data3).fit().rsquared
vif_Door=1/(1-rsq_Door)

rsq_Gear=smf.ols('Gears~age+KM+HP+cc+Doors+QT+Weight',data=data3).fit().rsquared
vif_Gear=1/(1-rsq_Gear)

rsq_QT=smf.ols('QT~age+KM+HP+cc+Doors+Gears+Weight',data=data3).fit().rsquared
vif_QT=1/(1-rsq_QT)

rsq_WT=smf.ols('Weight~age+KM+HP+cc+Doors+Gears+QT',data=data3).fit().rsquared
vif_WT=1/(1-rsq_WT)

# %% [markdown]
# Putting the values in Dataframe format

# %%
d1={'Variables':['age','KM','HP','cc','Doors','Gears','QT','Weight'],
    'Vif':[vif_age,vif_KM,vif_HP,vif_cc,vif_Door,vif_Gear,vif_QT,vif_WT]}
Vif_df=pd.DataFrame(d1)
Vif_df
# Out:
#   Variables       Vif
# 0       age  1.876236
# 1        KM  1.757178
# 2        HP  1.419180
# 3        cc  1.163470
# 4     Doors  1.155890
# 5     Gears  1.098843
# 6        QT  2.295375
# 7    Weight  2.487180

# %% [markdown]
# No variable has VIF>20, No Collinearity, so consider all varaibles in Regression equation

# %% [markdown]
# Residual Analysis
# Q-Q plot

# %%
import statsmodels.api as sm
qqplot=sm.qqplot(model.resid,line='q')
plt.title("Normal Q-Q plot of residuals")
plt.show()

# %%
#outliers
list(np.where(model.resid<-6000))
# Out:
# [array([220, 600, 959], dtype=int64)]

# %%
#Residual Plot for Homoscedasticity

# %%
def get_standardized_values( vals ):
    return (vals - vals.mean())/vals.std()

# %%
plt.scatter(get_standardized_values(model.fittedvalues),
            get_standardized_values(model.resid))

plt.title('Residual Plot')
plt.xlabel('Standardized Fitted values')
plt.ylabel('Standardized residual values')
plt.show()

# %%
#Residual Vs Regressors
#Age
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "age", fig=fig)
plt.show()

# %%
#KM
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "KM", fig=fig)
plt.show()

# %%
#HP
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "HP", fig=fig)
plt.show()

# %%
#cc
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "cc", fig=fig)
plt.show()

# %%
#Doors
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Doors", fig=fig)
plt.show()

# %%
#Gears
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Gears", fig=fig)
plt.show()

# %%
#QT
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "QT", fig=fig)
plt.show()

# %%
#Weight
fig = plt.figure(figsize=(15,8))
fig = sm.graphics.plot_regress_exog(model, "Weight", fig=fig)
plt.show()

# %%
#Model deletion diagnostics
#Cook's distance

# %%
model_influence = model.get_influence()
(c, _) = model_influence.cooks_distance

# %%
#Plot the influencers values using stem plot
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data3)), np.round(c, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# <ipython-input-45-0b5a83322e08>:3: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(data3)), np.round(c, 3))

# %%
np.argmax(c) , np.max(c)
# Out:
# (80, 78.7295058224916)

# %% [markdown]
# High influence points

# %%
from statsmodels.graphics.regressionplots import influence_plot #Leverage Value using High Influence Points
influence_plot(model)
plt.show()

# %%
k = data1.shape[1] # Leverage Cuttoff Value
n = data1.shape[0]
leverage_cutoff = 3*((k + 1)/n)
leverage_cutoff
# Out:
# 0.020891364902506964

# %% [markdown]
# Improving the model

# %% [markdown]
# From the above plot, it is evident that data point 80 is the influencers

# %%
data3[data3.index.isin([80])]
# Out:
#     Price  age     KM   HP     cc  Doors  Gears   QT  Weight
# 80  18950   25  20019  110  16000      5      5  100    1180

# %%
data4=data3.drop(data3.index[[80]],axis=0).reset_index(drop=True)
data4
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1429   7500   69  20544   86  1300      3      5   69    1025
# 1430  10845   72  19000   86  1300      3      5   69    1015
# 1431   8500   71  17016   86  1300      3      5   69    1015
# 1432   7250   70  16916   86  1300      3      5   69    1015
# 1433   6950   76      1  110  1600      5      5   19    1114
#
# [1434 rows x 9 columns]

# %%
model1 = smf.ols('Price~age+KM+HP+cc+Doors+Gears+QT+Weight',data=data4).fit()
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.868
# Model:                            OLS   Adj. R-squared:                  0.867
# Method:                 Least Squares   F-statistic:                     1172.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        21:07:05   Log-Likelihood:                -12326.
# No. Observations:                1434   AIC:                         2.467e+04
# Df Residuals:                    1425   BIC:                         2.472e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -6197.9334   1383.989     -4.478      0.000   -8912.808   -3483.059
# ...

# %%
####R^2 value has increased but Doors still remains insignificant

# %%
model_influence = model1.get_influence()
(c1, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data4)), np.round(c1, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# <ipython-input-66-53c248be0825>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(data4)), np.round(c1, 3))

# %%
np.argmax(c1),np.max(c1)
# Out:
# (219, 2.2253513655270813)

# %%
data5=data4.drop(data4.index[[219]],axis=0).reset_index(drop=True)
data5
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1428   7500   69  20544   86  1300      3      5   69    1025
# 1429  10845   72  19000   86  1300      3      5   69    1015
# 1430   8500   71  17016   86  1300      3      5   69    1015
# 1431   7250   70  16916   86  1300      3      5   69    1015
# 1432   6950   76      1  110  1600      5      5   19    1114
#
# [1433 rows x 9 columns]

# %%
model2= smf.ols('Price~age+KM+HP+cc+Doors+Gears+QT+Weight',data=data5).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     1264.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        21:09:25   Log-Likelihood:                -12270.
# No. Observations:                1433   AIC:                         2.456e+04
# Df Residuals:                    1424   BIC:                         2.461e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.018e+04   1398.103     -7.279      0.000   -1.29e+04   -7433.579
# ...

# %%
####R^2 value has increased but Doors still remains insignificant

# %%
model_influence = model2.get_influence()
(c2, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data5)), np.round(c2, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# <ipython-input-72-2ba69f2283ac>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(data5)), np.round(c2, 3))

# %%
np.argmax(c2),np.max(c2)
# Out:
# (957, 2.530779623276654)

# %%
data6=data5.drop(data5.index[[957]],axis=0).reset_index(drop=True)
data6
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1427   7500   69  20544   86  1300      3      5   69    1025
# 1428  10845   72  19000   86  1300      3      5   69    1015
# 1429   8500   71  17016   86  1300      3      5   69    1015
# 1430   7250   70  16916   86  1300      3      5   69    1015
# 1431   6950   76      1  110  1600      5      5   19    1114
#
# [1432 rows x 9 columns]

# %%
model3= smf.ols('Price~age+KM+HP+cc+Doors+Gears+QT+Weight',data=data6).fit()
model3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.884
# Model:                            OLS   Adj. R-squared:                  0.883
# Method:                 Least Squares   F-statistic:                     1355.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        21:12:13   Log-Likelihood:                -12218.
# No. Observations:                1432   AIC:                         2.445e+04
# Df Residuals:                    1423   BIC:                         2.450e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.468e+04   1436.358    -10.222      0.000   -1.75e+04   -1.19e+04
# ...

# %%
####R^2 value has increased also p value of doors is < 0.05; lets check for influence points

# %%
model_influence = model3.get_influence()
(c3, _) = model_influence.cooks_distance

# %%
fig = plt.subplots(figsize=(20, 7))
plt.stem(np.arange(len(data6)), np.round(c3, 3))
plt.xlabel('Row index')
plt.ylabel('Cooks Distance')
plt.show()
# Out:
# <ipython-input-78-70c9673709f9>:2: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   plt.stem(np.arange(len(data6)), np.round(c3, 3))

# %%
np.argmax(c3),np.max(c3)
# Out:
# (598, 0.31689035401452564)

# %%
data7=data6.drop(data6.index[[598]],axis=0).reset_index(drop=True)
data7
# Out:
#       Price  age     KM   HP    cc  Doors  Gears   QT  Weight
# 0     13500   23  46986   90  2000      3      5  210    1165
# 1     13750   23  72937   90  2000      3      5  210    1165
# 2     13950   24  41711   90  2000      3      5  210    1165
# 3     14950   26  48000   90  2000      3      5  210    1165
# 4     13750   30  38500   90  2000      3      5  210    1170
# ...     ...  ...    ...  ...   ...    ...    ...  ...     ...
# 1426   7500   69  20544   86  1300      3      5   69    1025
# 1427  10845   72  19000   86  1300      3      5   69    1015
# 1428   8500   71  17016   86  1300      3      5   69    1015
# 1429   7250   70  16916   86  1300      3      5   69    1015
# 1430   6950   76      1  110  1600      5      5   19    1114
#
# [1431 rows x 9 columns]

# %%
final_model= smf.ols('Price~age+KM+HP+cc+Doors+Gears+QT+Weight',data=data7).fit()
final_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  Price   R-squared:                       0.888
# Model:                            OLS   Adj. R-squared:                  0.888
# Method:                 Least Squares   F-statistic:                     1413.
# Date:                Wed, 14 Jul 2021   Prob (F-statistic):               0.00
# Time:                        21:19:40   Log-Likelihood:                -12182.
# No. Observations:                1431   AIC:                         2.438e+04
# Df Residuals:                    1422   BIC:                         2.443e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.613e+04   1423.155    -11.333      0.000   -1.89e+04   -1.33e+04
# ...

# %% [markdown]
# As most of the variables has p value < 0.05, no more influence points also Rsquared value is 0.88 and our errors are minimized, we consider this model as our final model.

# %%
#Predict for new values
new_data=pd.DataFrame({'age':14,"KM":39700,"HP":90,"cc":1300,"Doors":4,"Gears":5,"QT":69,"Weight":1012},index=[0])
new_data
# Out:
#    age     KM  HP    cc  Doors  Gears  QT  Weight
# 0   14  39700  90  1300      4      5  69    1012

# %%
final_model.predict(new_data)
# Out:
# 0    14468.765456
# dtype: float64

# %%
# Automatic Prediction of Price with 88% accuracy
pred_y=final_model.predict(data7)
pred_y
# Out:
# 0       16345.352610
# 1       15886.635544
# 2       16328.224968
# 3       15996.318854
# 4       15883.424182
#             ...
# 1426     9161.230587
# 1427     8536.091326
# 1428     8681.531063
# 1429     8793.668694
# 1430    10860.695492
# Length: 1431, dtype: float64
